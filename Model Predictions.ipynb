# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Import

# %%
data_d = pd.read_csv("day.csv")

# %%
data_d.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
data_h = pd.read_csv("hour.csv")

# %%
data_h.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ## Data Cleaning and EDA

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
data_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
data_d.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_h.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_d['dteday'] = pd.to_datetime(data_d['dteday'])

# %%
data_h['dteday'] = pd.to_datetime(data_h['dteday'])

# %%
data_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_d = data_d.drop(columns=['instant'])
data_h = data_h.drop(columns= ['instant'])

# %%
print(data_d.columns, "day")
print(data_h.columns, "hour")
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object') day
# Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object') hour

# %% [markdown]
# ## -----------------------------------------------------------------

# %%
# Distribution of total bike rentals
plt.figure(figsize=(7,5))
sns.histplot(data_d['cnt'], kde=True)
plt.title("Distribution of Total Bike Rentals")
plt.show()

# %%
# Monthly rental count
monthly_counts = data_d.groupby('mnth')['cnt'].sum().reset_index()

monthly_counts.style.background_gradient(
    subset=['cnt'], cmap='YlGnBu'
)
# Out:
# <style type="text/css">
# #T_7256f_row0_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_7256f_row1_col1 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_7256f_row2_col1 {
#   background-color: #61c2bf;
#   color: #000000;
# }
# #T_7256f_row3_col1 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_7256f_row4_col1 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_7256f_row5_col1 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_7256f_row6_col1 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_7256f_row7_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_7256f_row8_col1 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_7256f_row9_col1 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_7256f_row10_col1 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_7256f_row11_col1 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# </style>
# <table id="T_7256f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7256f_level0_col0" class="col_heading level0 col0" >mnth</th>
#       <th id="T_7256f_level0_col1" class="col_heading level0 col1" >cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7256f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7256f_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7256f_row0_col1" class="data row0 col1" >134933</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7256f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7256f_row1_col1" class="data row1 col1" >151352</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7256f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7256f_row2_col1" class="data row2 col1" >228920</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7256f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7256f_row3_col1" class="data row3 col1" >269094</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7256f_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_7256f_row4_col1" class="data row4 col1" >331686</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7256f_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_7256f_row5_col1" class="data row5 col1" >346342</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7256f_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_7256f_row6_col1" class="data row6 col1" >344948</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7256f_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_7256f_row7_col1" class="data row7 col1" >351194</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7256f_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_7256f_row8_col1" class="data row8 col1" >345991</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7256f_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_7256f_row9_col1" class="data row9 col1" >322352</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7256f_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_7256f_row10_col1" class="data row10 col1" >254831</td>
#     </tr>
#     <tr>
#       <th id="T_7256f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7256f_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_7256f_row11_col1" class="data row11 col1" >211036</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Bike rentals over the time 
plt.figure(figsize=(12,5))
plt.plot(data_d['dteday'], data_d['cnt'])
plt.title("Bike Rentals Over Time")
plt.xlabel("Date")
plt.ylabel("Count")
plt.show()

# %%
# Average rentals by the season
plt.figure(figsize=(7,5))
sns.barplot(x='season', y='cnt', data=data_d)
plt.title("Average Rentals by Season")
plt.show()

# %%
# Rentals on weekdays and working days
sns.barplot(x='workingday', y='cnt', data=data_d)
plt.title("Effect of Working Day on Rentals")
plt.show()

# %%
# Scatter plot for Temp vs Rentals
plt.figure(figsize=(7,5))
sns.scatterplot(x='temp', y='cnt', data=data_d)
plt.title("Temperature vs Rentals")
plt.show()

# %% [markdown]
# ## Feature Selection

# %%
cols_to_drop = ['casual', 'registered', 'dteday','yr']

data_d = data_d.drop(columns=cols_to_drop)
data_h = data_h.drop(columns=cols_to_drop)

# %%
data_d.describe()
# Out:
#            season        mnth     holiday     weekday  workingday  weathersit  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    6.519836    0.028728    2.997264    0.683995    1.395349
# std      1.110807    3.451913    0.167155    2.004787    0.465233    0.544894
# min      1.000000    1.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    4.000000    0.000000    1.000000    0.000000    1.000000
# 50%      3.000000    7.000000    0.000000    3.000000    1.000000    1.000000
# 75%      3.000000   10.000000    0.000000    5.000000    1.000000    2.000000
# max      4.000000   12.000000    1.000000    6.000000    1.000000    3.000000
#
#              temp       atemp         hum   windspeed          cnt
# count  731.000000  731.000000  731.000000  731.000000   731.000000
# mean     0.495385    0.474354    0.627894    0.190486  4504.348837
# std      0.183051    0.162961    0.142429    0.077498  1937.211452
# min      0.059130    0.079070    0.000000    0.022392    22.000000
# 25%      0.337083    0.337842    0.520000    0.134950  3152.000000
# 50%      0.498333    0.486733    0.626667    0.180975  4548.000000
# 75%      0.655417    0.608602    0.730209    0.233214  5956.000000
# max      0.861667    0.840896    0.972500    0.507463  8714.000000

# %%
data_h.describe()
# Out:
#              season          mnth            hr       holiday       weekday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      6.537775     11.546752      0.028770      3.003683
# std        1.106918      3.438776      6.914405      0.167165      2.005771
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%        2.000000      4.000000      6.000000      0.000000      1.000000
# 50%        3.000000      7.000000     12.000000      0.000000      3.000000
# 75%        3.000000     10.000000     18.000000      0.000000      5.000000
# max        4.000000     12.000000     23.000000      1.000000      6.000000
#
#          workingday    weathersit          temp         atemp           hum  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.682721      1.425283      0.496987      0.475775      0.627229
# std        0.465431      0.639357      0.192556      0.171850      0.192930
# min        0.000000      1.000000      0.020000      0.000000      0.000000
# 25%        0.000000      1.000000      0.340000      0.333300      0.480000
# 50%        1.000000      1.000000      0.500000      0.484800      0.630000
# 75%        1.000000      2.000000      0.660000      0.621200      0.780000
# max        1.000000      4.000000      1.000000      1.000000      1.000000
#
#           windspeed           cnt
# count  17379.000000  17379.000000
# mean       0.190098    189.463088
# std        0.122340    181.387599
# min        0.000000      1.000000
# 25%        0.104500     40.000000
# 50%        0.194000    142.000000
# 75%        0.253700    281.000000
# max        0.850700    977.000000

# %% [markdown]
# ## EDA for daily data

# %%
# Correlation heatmap
plt.figure(figsize=(12,6))
sns.heatmap(data_d.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Daily Data)")
plt.show()

# %%
#Distribution of Target (cnt)
plt.figure(figsize=(7,5))
sns.histplot(data_d['cnt'], kde=True)
plt.title("Distribution of Daily Total Rentals")
plt.show()

# %%
# Weather vs Rentals
sns.barplot(x='weathersit', y='cnt', data=data_d)
plt.title("Weather Situation vs Daily Rentals")
plt.show()

# %% [markdown]
# ## EDA for Hourly data

# %%
# Correlation heatmap
plt.figure(figsize=(12,6))
sns.heatmap(data_h.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Hourly Data)")
plt.show()

# %%
# Hourly rental pattern
plt.figure(figsize=(10,5))
sns.lineplot(x='hr', y='cnt', data=data_h)
plt.title("Hourly Rental Pattern")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='hr', y='cnt', hue='season', data=data_h)
plt.title("Hourly Rentals by Season")
plt.show()

# %% [markdown]
# ## ---------------------------------------------------------

# %% [markdown]
# ## Outlier detection for hourly data data using Boxplot

# %%
# Define continuous variables to check for outliers

cols_to_check = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']

# Visualizing Outliers for Hourly Data
plt.figure(figsize=(15, 10))
for i, col in enumerate(cols_to_check):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(x=data_h[col])
    plt.title(f'Hourly: {col}')
plt.tight_layout()
plt.show()

# %%
# Function to remove outliers from datasets

def remove_outliers_iqr(df, columns):
   
    df_clean = df.copy()
    
    for col in columns:
        Q1 = df_clean[col].quantile(0.25)
        Q3 = df_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Filter the data: Keep rows within bounds
        df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]
        
    return df_clean


target_cols = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']

# %%
# Remove outliers

data_h_clean = remove_outliers_iqr(data_h, target_cols)

# Verify Results

print(f"Original Rows: {data_h.shape[0]}")
print(f"Cleaned Rows:  {data_h_clean.shape[0]}")
print(f"Rows Dropped:  {data_h.shape[0] - data_h_clean.shape[0]}")
# Out:
# Original Rows: 17379
# Cleaned Rows:  16535
# Rows Dropped:  844

# %% [markdown]
# ## Outlier detection for daily data using Boxplot

# %%
# Visualizing Outliers for Daily Data
plt.figure(figsize=(15, 10))
for i, col in enumerate(cols_to_check):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(x=data_d[col])
    plt.title(f'Daily: {col}')
plt.tight_layout()
plt.show()

# %%
# Remove outliers

data_d_clean = remove_outliers_iqr(data_d, target_cols)

# Verify Results

print(f"Original Rows: {data_d.shape[0]}")
print(f"Cleaned Rows:  {data_d_clean.shape[0]}")
print(f"Rows Dropped:  {data_d.shape[0] - data_d_clean.shape[0]}")
# Out:
# Original Rows: 731
# Cleaned Rows:  717
# Rows Dropped:  14

# %% [markdown]
# ## -----------------------------------------------------------------

# %% [markdown]
# ## Model Training

# %% [markdown]
# #### Model training for hourly data

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor # Import Random Forest
from sklearn.metrics import mean_squared_error, r2_score


# Define predictors (X) and target (y)
X_h = data_h_clean.drop(['cnt'], axis=1)
y_h = data_h_clean['cnt']

# %%
# Split into training and testing sets
X_train_h, X_test_h, y_train_h, y_test_h = train_test_split(X_h, y_h, test_size=0.2, random_state=42)

# %%
# Initialize Random Forest Regressor
rf_h = RandomForestRegressor(n_estimators=100, random_state=42)
rf_h.fit(X_train_h, y_train_h)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict on test data
y_pred_h = rf_h.predict(X_test_h)

# %%
# Calculate metrics
mse_h = mean_squared_error(y_test_h, y_pred_h)
r2_h = r2_score(y_test_h, y_pred_h)

print(f"Mean Squared Error: {mse_h:.2f}")
print(f"R-squared Score: {r2_h:.2f}")
# Out:
# Mean Squared Error: 3440.35
# R-squared Score: 0.85

# %% [markdown]
# #### Model Training for daily data

# %%
# Define predictors (X) and target (y) for daily data
X_d = data_d_clean.drop(['cnt'], axis=1)
y_d = data_d_clean['cnt']

# %%
# Dataset split
X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(X_d, y_d, test_size=0.2, random_state=42)

# %%
# Initialize Random Forest Regressor
rf_d = RandomForestRegressor(n_estimators=100, random_state=42)
rf_d.fit(X_train_d, y_train_d)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict on test data
y_pred_d = rf_d.predict(X_test_d)

# %%
# Calculate metrics
mse_d = mean_squared_error(y_test_d, y_pred_d)
r2_d = r2_score(y_test_d, y_pred_d)

print(f"Mean Squared Error: {mse_d:.2f}")
print(f"R-squared Score: {r2_d:.2f}")
# Out:
# Mean Squared Error: 1334801.61
# R-squared Score: 0.65

# %% [markdown]
# ### ------------------------------------------------

# %% [markdown]
# ## Hyperparameter Tuning for hourly data

# %%
# Initialize Random Forest with "Stronger" Parameters directly
rf_h_manual = RandomForestRegressor(n_estimators=1000, max_depth=20, random_state=42, n_jobs=-2)

# %%
# 2. Train
rf_h_manual.fit(X_train_h, y_train_h)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=1000, n_jobs=-2,
#                       random_state=42)

# %%
# 3. Evaluate
y_pred_h_manual = rf_h_manual.predict(X_test_h)

mse_h_manual = mean_squared_error(y_test_h, y_pred_h_manual)
r2_h_manual = r2_score(y_test_h, y_pred_h_manual)

# %%
print(f"Hourly Data Tuned MSE: {mse_h_manual:.2f}")
print(f"Hourly Data Tuned R2:  {r2_h_manual:.4f}")
# Out:
# Hourly Data Tuned MSE: 3442.51
# Hourly Data Tuned R2:  0.8547

# %% [markdown]
# ## Hyperparameter Tuning for Daily data

# %%
# 1. Initialize with parameters suited for smaller data
rf_d_manual = RandomForestRegressor(n_estimators=1000, max_depth=15, min_samples_leaf=4, random_state=42)

# %%
# 2. Train
print("Training Daily Model with optimized settings...")
rf_d_manual.fit(X_train_d, y_train_d)
# Out:
# Training Daily Model with optimized settings...
# RandomForestRegressor(max_depth=15, min_samples_leaf=4, n_estimators=1000,
#                       random_state=42)

# %%
# 3. Evaluate
y_pred_d_manual = rf_d_manual.predict(X_test_d)

mse_d_manual = mean_squared_error(y_test_d, y_pred_d_manual)
r2_d_manual = r2_score(y_test_d, y_pred_d_manual)

# %%
print(f"Daily Data Tuned MSE: {mse_d_manual:.2f}")
print(f"Daily Data Tuned R2:  {r2_d_manual:.4f}")
# Out:
# Daily Data Tuned MSE: 1298284.01
# Daily Data Tuned R2:  0.6553

# %% [markdown]
# ### Test & Train accuracy

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test, name):
    # 1. Predict on Training Data
    y_train_pred = model.predict(X_train)
    # 2. Predict on Testing Data
    y_test_pred = model.predict(X_test)

#  Calculate R2 Scores (Accuracy)
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    
#  Calculate RMSE (Error)
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
    
    print(f"--- {name} Data Performance ---")
    print(f"Training R2 Score: {train_r2:.4f} (Accuracy on seen data)")
    print(f"Testing  R2 Score: {test_r2:.4f} (Accuracy on unseen data)")
    print(f"Gap (Overfitting): {train_r2 - test_r2:.4f}")
    print(f"Training RMSE:     {train_rmse:.2f}")
    print(f"Testing  RMSE:     {test_rmse:.2f}")
    print("="*40)
    return train_r2, test_r2

# %%
# --- Run for Hourly Data ---
# Replace 'rf_h' with 'rf_h_manual' or 'rf_h_tuned' if you used specific tuning variables
r2_train_h, r2_test_h = evaluate_model(rf_h, X_train_h, y_train_h, X_test_h, y_test_h, "HOURLY")

# --- Run for Daily Data ---
# Replace 'rf_d' with 'rf_d_manual' or 'rf_d_tuned'
r2_train_d, r2_test_d = evaluate_model(rf_d, X_train_d, y_train_d, X_test_d, y_test_d, "DAILY")
# Out:
# --- HOURLY Data Performance ---
# Training R2 Score: 0.9809 (Accuracy on seen data)
# Testing  R2 Score: 0.8547 (Accuracy on unseen data)
# Gap (Overfitting): 0.1262
# Training RMSE:     21.60
# Testing  RMSE:     58.65
# ========================================
# --- DAILY Data Performance ---
# Training R2 Score: 0.9435 (Accuracy on seen data)
# Testing  R2 Score: 0.6456 (Accuracy on unseen data)
# Gap (Overfitting): 0.2979
# Training RMSE:     458.22
# Testing  RMSE:     1155.34
# ========================================

# %% [markdown]
# ### Predicting demand for next 6 hours

# %%
# 1. Get the last known data point (The "Current" state)
last_row_h = data_h_clean.iloc[-1]

feature_cols_h = X_train_h.columns 

# 2. Generate Data for Next 6 Hours
future_data_h = []
current_hr = int(last_row_h['hr'])
current_weekday = int(last_row_h['weekday'])

for i in range(1, 7): # Next 6 hours
    next_hour = (current_hr + i) % 24
    
    # If hour rolls over 23 -> 0, it's the next day
    day_increment = (current_hr + i) // 24
    next_weekday = (current_weekday + day_increment) % 7
    
    # Create a new row based on the last known row
    new_row = last_row_h.copy()
    new_row['hr'] = next_hour
    new_row['weekday'] = next_weekday
    
    # Assume 'workingday' (0=Sun, 6=Sat are not working days)
    if next_weekday == 0 or next_weekday == 6:
        new_row['workingday'] = 0
    else:
        new_row['workingday'] = 1
        
    # Append to list
    future_data_h.append(new_row)

# 3. Create DataFrame
X_future_h = pd.DataFrame(future_data_h)
X_future_h = X_future_h[feature_cols_h]

# 4. Predict using the trained model 
future_preds_h = rf_h_manual.predict(X_future_h)

# 5. Display Results
print("--- PREDICTED DEMAND: NEXT 6 HOURS ---")
for i, pred in enumerate(future_preds_h, 1):
    hr = X_future_h.iloc[i-1]['hr']
    print(f"Next Hour {i} (Hour {int(hr)}:00): {int(pred)} rentals")
# Out:
# --- PREDICTED DEMAND: NEXT 6 HOURS ---
# Next Hour 1 (Hour 0:00): 13 rentals
# Next Hour 2 (Hour 1:00): 8 rentals
# Next Hour 3 (Hour 2:00): 3 rentals
# Next Hour 4 (Hour 3:00): 3 rentals
# Next Hour 5 (Hour 4:00): 2 rentals
# Next Hour 6 (Hour 5:00): 12 rentals

# %%
# 2. Generate Data for Next 6 Hours
future_data_h = []
current_hr = int(last_row_h['hr'])
current_weekday = int(last_row_h['weekday'])

for i in range(1, 7): # Next 6 hours
    next_hour = (current_hr + i) % 24
    
    # If hour rolls over 23 -> 0, it's the next day
    day_increment = (current_hr + i) // 24
    next_weekday = (current_weekday + day_increment) % 7
    
    # Creating a new row based on the last known row
    new_row = last_row_h.copy()
    new_row['hr'] = next_hour
    new_row['weekday'] = next_weekday
    
    # Assume 'workingday' (0=Sun, 6=Sat are not working days)
    if next_weekday == 0 or next_weekday == 6:
        new_row['workingday'] = 0
    else:
        new_row['workingday'] = 1
        
    # Append to list 
    future_data_h.append(new_row)

# %%
# 3. Create DataFrame
X_future_h = pd.DataFrame(future_data_h)
X_future_h = X_future_h[feature_cols_h]

# %%
# 4. Predict using the trained model 
future_preds_h = rf_h_manual.predict(X_future_h)

# %%
# 5. Display Results
print("--- PREDICTED DEMAND: NEXT 6 HOURS ---")
for i, pred in enumerate(future_preds_h, 1):
    hr = X_future_h.iloc[i-1]['hr']
    print(f"Next Hour {i} (Hour {int(hr)}:00): {int(pred)} rentals")
# Out:
# --- PREDICTED DEMAND: NEXT 6 HOURS ---
# Next Hour 1 (Hour 0:00): 13 rentals
# Next Hour 2 (Hour 1:00): 8 rentals
# Next Hour 3 (Hour 2:00): 3 rentals
# Next Hour 4 (Hour 3:00): 3 rentals
# Next Hour 5 (Hour 4:00): 2 rentals
# Next Hour 6 (Hour 5:00): 12 rentals

# %% [markdown]
# ### Predicting demand for next 6 days

# %%
# 1. Get the last known data point
last_row_d = data_d_clean.iloc[-1]
feature_cols_d = X_train_d.columns

# %%
# 2. Generate Data for Next 6 Days
future_data_d = []
current_weekday = int(last_row_d['weekday'])

for i in range(1, 7): # Next 6 days
    next_weekday = (current_weekday + i) % 7
    
    new_row = last_row_d.copy()
    new_row['weekday'] = next_weekday
    
    # Update workingday logic
    if next_weekday == 0 or next_weekday == 6:
        new_row['workingday'] = 0
    else:
        new_row['workingday'] = 1
        
   
    future_data_d.append(new_row)

# %%
# 3. Prepare DataFrame
X_future_d = pd.DataFrame(future_data_d)
X_future_d = X_future_d[feature_cols_d]

# %%
# 4. Predict 
future_preds_d = rf_d_manual.predict(X_future_d)

# %%
# 5. Display Results
print("\n--- PREDICTED DEMAND: NEXT 6 DAYS ---")
days_map = {0:"Sun", 1:"Mon", 2:"Tue", 3:"Wed", 4:"Thu", 5:"Fri", 6:"Sat"}

for i, pred in enumerate(future_preds_d, 1):
    wd = int(X_future_d.iloc[i-1]['weekday'])
    print(f"Next Day {i} ({days_map[wd]}): {int(pred)} rentals")
# Out:
# --- PREDICTED DEMAND: NEXT 6 DAYS ---
# Next Day 1 (Tue): 1951 rentals
# Next Day 2 (Wed): 1923 rentals
# Next Day 3 (Thu): 1915 rentals
# Next Day 4 (Fri): 1896 rentals
# Next Day 5 (Sat): 1785 rentals
# Next Day 6 (Sun): 1887 rentals

# %% [markdown]
# ### Visualize Hourly Forecast

# %%
# Take the last 24 hours of actual known data
last_24_hours = data_h_clean['cnt'].iloc[-24:].values
# Create a sequence for plotting
history_indices = range(24)
future_indices = range(24, 30)

plt.figure(figsize=(10, 5))
plt.plot(history_indices, last_24_hours, label='Historical Data (Last 24h)', marker='o')
plt.plot(future_indices, future_preds_h, label='Forecast (Next 6h)', marker='o', linestyle='--', color='red')

plt.title('Hourly Bike Rental Forecast')
plt.xlabel('Time Steps')
plt.ylabel('Bike Rentals')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
