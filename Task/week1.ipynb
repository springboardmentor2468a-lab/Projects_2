# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hour=pd.read_csv('hour.csv.zip')
day=pd.read_csv('day.csv')

# %%
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour = hour.drop(['instant','dteday','yr','casual', 'registered'], axis=1)
day = day.drop(['instant','dteday','yr','casual', 'registered'], axis=1)

# %%
day.head()
# Out:
#    season  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1     1        0        1           1           2  14.110847
# 1       1     1        0        2           1           2  14.902598
# 2       1     1        0        3           1           1   8.050924
# 3       1     1        0        4           1           1   8.200000
# 4       1     1        0        5           1           1   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %%
hour.head()
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
# 3       1     1   3        0        6           0           1  0.24  0.2879
# 4       1     1   4        0        6           0           1  0.24  0.2879
#
#     hum  windspeed  cnt
# 0  0.81        0.0   16
# 1  0.80        0.0   40
# 2  0.80        0.0   32
# 3  0.75        0.0   13
# 4  0.75        0.0    1

# %%
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      17379 non-null  int64
#  1   mnth        17379 non-null  int64
#  2   hr          17379 non-null  int64
#  3   holiday     17379 non-null  int64
#  4   weekday     17379 non-null  int64
#  5   workingday  17379 non-null  int64
#  6   weathersit  17379 non-null  int64
#  7   temp        17379 non-null  float64
#  8   atemp       17379 non-null  float64
#  9   hum         17379 non-null  float64
#  10  windspeed   17379 non-null  float64
#  11  cnt         17379 non-null  int64
# dtypes: float64(4), int64(8)
# memory usage: 1.6 MB

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   mnth        730 non-null    int64
#  2   holiday     730 non-null    int64
#  3   weekday     730 non-null    int64
#  4   workingday  730 non-null    int64
#  5   weathersit  730 non-null    int64
#  6   temp        730 non-null    float64
#  7   atemp       730 non-null    float64
#  8   hum         730 non-null    float64
#  9   windspeed   730 non-null    float64
#  10  cnt         730 non-null    int64
# dtypes: float64(4), int64(7)
# memory usage: 62.9 KB

# %%
hour.describe()
# Out:
#              season          mnth            hr       holiday       weekday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      6.537775     11.546752      0.028770      3.003683
# std        1.106918      3.438776      6.914405      0.167165      2.005771
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%        2.000000      4.000000      6.000000      0.000000      1.000000
# 50%        3.000000      7.000000     12.000000      0.000000      3.000000
# 75%        3.000000     10.000000     18.000000      0.000000      5.000000
# max        4.000000     12.000000     23.000000      1.000000      6.000000
#
#          workingday    weathersit          temp         atemp           hum  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.682721      1.425283      0.496987      0.475775      0.627229
# ...

# %%
day.describe()
# Out:
#            season        mnth     holiday     weekday  workingday  weathersit  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     2.498630    6.526027    0.028767    2.995890    0.690411    1.394521
# std      1.110184    3.450215    0.167266    2.000339    0.462641    0.544807
# min      1.000000    1.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    4.000000    0.000000    1.000000    0.000000    1.000000
# 50%      3.000000    7.000000    0.000000    3.000000    1.000000    1.000000
# 75%      3.000000   10.000000    0.000000    5.000000    1.000000    2.000000
# max      4.000000   12.000000    1.000000    6.000000    1.000000    3.000000
#
#              temp       atemp         hum   windspeed          cnt
# count  730.000000  730.000000  730.000000  730.000000   730.000000
# mean    20.319259   23.726322   62.765175   12.763620  4508.006849
# ...

# %%
hour.isnull().sum()
# Out:
# season        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64

# %%
day.isnull().sum()
# Out:
# season        0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64

# %%
hour.duplicated().sum()
# Out:
# np.int64(2)

# %%
day.duplicated().sum()
# Out:
# np.int64(0)

# %%
hour.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
day.shape
# Out:
# (730, 11)

# %%
# Check for impossible or inconsistent values

print("Negative temperature values:", (hour['temp'] < 0).sum())
print("Negative atemp values:", (hour['atemp'] < 0).sum())
print("Negative humidity values:", (hour['hum'] < 0).sum())
print("Humidity > 1 values:", (hour['hum'] > 1).sum())
print("Negative windspeed values:", (hour['windspeed'] < 0).sum())
print("Hours outside 0–23:", (~hour['hr'].between(0, 23)).sum())
print("Months outside 1–12:", (~hour['mnth'].between(1, 12)).sum())
# Out:
# Negative temperature values: 0
# Negative atemp values: 0
# Negative humidity values: 0
# Humidity > 1 values: 0
# Negative windspeed values: 0
# Hours outside 0–23: 0
# Months outside 1–12: 0

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=hour, x='hr', y='cnt')
plt.title("Average Bike Rentals by Hour of the Day")
plt.xlabel("Hour")
plt.ylabel("Average Rental Count")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=hour, x='hr', y='cnt')
plt.title("Average Monthly Bike Rentals")
plt.xlabel("Month")
plt.ylabel("Average Rental Count")
plt.grid(True)
plt.show()
