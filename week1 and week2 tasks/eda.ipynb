# %%
import pandas as pd

day = pd.read_csv("day.csv")
hour = pd.read_csv("hour.csv")

print("DAY CSV:")
display(day.head())

print("HOUR CSV:")
display(hour.head())
# Out:
# DAY CSV:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# HOUR CSV:
# ...

# %%
print("Missing in DAY:")
display(day.isna().sum())

print("Missing in HOUR:")
display(hour.isna().sum())
# Out:
# Missing in DAY:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
# Missing in HOUR:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day.columns = [c.lower().strip().replace(" ", "_") for c in day.columns]
hour.columns = [c.lower().strip().replace(" ", "_") for c in hour.columns]

# %%
day["_source"] = "day"
hour["_source"] = "hour"

merged = pd.concat([day, hour], ignore_index=True)
display(merged.head())
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt _source  hr
# 0   985     day NaN
# 1   801     day NaN
# 2  1349     day NaN
# ...

# %%
merged.isna().sum()
# Out:
# instant         0
# dteday          0
# season          0
# yr              0
# mnth            0
# holiday         0
# weekday         0
# workingday      0
# weathersit      0
# temp            0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# _source         0
# hr            731
# dtype: int64

# %%
for col in merged.select_dtypes(include="number").columns:
    merged[col].fillna(merged[col].median(), inplace=True)

for col in merged.select_dtypes(include="object").columns:
    merged[col].fillna(merged[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-2183299079.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged[col].fillna(merged[col].median(), inplace=True)
# /tmp/ipython-input-2183299079.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
merged.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# _source       0
# hr            0
# dtype: int64

# %%
merged.head(30)
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1        0        6           0
# 1         2  2011-01-02       1   0     1        0        0           0
# 2         3  2011-01-03       1   0     1        0        1           1
# 3         4  2011-01-04       1   0     1        0        2           1
# 4         5  2011-01-05       1   0     1        0        3           1
# 5         6  2011-01-06       1   0     1        0        4           1
# 6         7  2011-01-07       1   0     1        0        5           1
# 7         8  2011-01-08       1   0     1        0        6           0
# 8         9  2011-01-09       1   0     1        0        0           0
# 9        10  2011-01-10       1   0     1        0        1           1
# 10       11  2011-01-11       1   0     1        0        2           1
# 11       12  2011-01-12       1   0     1        0        3           1
# ...

# %%
merged["cnt"].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(merged.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
  merged.to_csv("cleaned_merged.csv", index=False)

# %%
from google.colab import files
files.download("cleaned_merged.csv")
